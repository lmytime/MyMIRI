# %%
# Packages that allow us to get information about objects:
import asdf
import copy
import os
import shutil
import glob
import warnings

# Numpy library:
import numpy as np
# Astropy tools:
from astropy.io import fits

# %%
import jwst

print('Pipeline version:', jwst.__version__)

# List of possible data quality flags
from jwst import datamodels
from jwst.datamodels import dqflags
# To read association file
import json
# Out:
# Pipeline version: 1.12.5

# %%
#Uncomment below two lines if you have not defined CRDS elsewhere
os.environ['CRDS_PATH']= '/data/public/jwst_crds'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

# %% [markdown]
# ## Stage 2

# %%
# The entire calwebb_image2 pipeline
from jwst.pipeline import calwebb_image2

# Individual steps that make up calwebb_image2
from jwst.background import BackgroundStep
from jwst.assign_wcs import AssignWcsStep
from jwst.flatfield import FlatFieldStep
from jwst.photom import PhotomStep
from jwst.resample import ResampleStep

# %%
input_dir='./stage1/'
output_dir = './stage2/'
output_dir_bkg = output_dir+'bkg/'
output_dir_assign_wcs = output_dir+'assign_wcs/'
output_dir_flatfield = output_dir+'flatfield/'
output_dir_photom = output_dir+'photom/'
output_dir_resample = output_dir+'resample/'

# %%
os.makedirs(output_dir, exist_ok=True)
os.makedirs(output_dir_bkg, exist_ok=True)
os.makedirs(output_dir_assign_wcs, exist_ok=True)
os.makedirs(output_dir_flatfield, exist_ok=True)
os.makedirs(output_dir_photom, exist_ok=True)
os.makedirs(output_dir_resample, exist_ok=True)

os.system('cp '+input_dir+'*_rate.fits '+output_dir+'')
# Out:
# 0

# %%
# Create and open the association file and load into json object
os.system('asn_from_list -o level2_asn.json -r DMSLevel2bBase '+output_dir+'*_rate.fits')
asn_file ='level2_asn.json'
# Out:
# 2024-01-03 21:13:35,526 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)

# %%
#If some parameters are known to have better results with certain value use the dictionary
parameter_dict = {"bkg_subtract": {"sigma":4,"output_dir": output_dir_bkg,"save_results": True},
                  "assign_wcs": {"output_dir": output_dir_assign_wcs,"save_results": True},
                  "flat_field": {"output_dir": output_dir_flatfield,"save_results": True},
                  "photom": {"output_dir": output_dir_photom,"save_results": True},
                  "resample": {"pixfrac": 1.0, "output_dir": output_dir_resample,"save_results": True},
                 }

# %%
call_output = calwebb_image2.Image2Pipeline.call(asn_file, output_dir=output_dir, save_results=True, steps=parameter_dict,logcfg='stage2-log.cfg')
# Out:
# 2024-01-03 17:30:35,675 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-01-03 17:30:35,740 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2024-01-03 17:30:35,741 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2024-01-03 17:30:35,743 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2024-01-03 17:30:35,744 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2024-01-03 17:30:35,744 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2024-01-03 17:30:35,746 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2024-01-03 17:30:35,914 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args ('level2_asn.json',).
# 2024-01-03 17:30:35,918 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/bkg/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 4, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/assign_wcs/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/flatfield/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/photom/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/resample/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}}}
# 2024-01-03 17:30:35,936 - stpipe.Image2Pipeline - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-01-03 17:30:35,989 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw01837014001_02101_00001_mirimage_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2024-01-03 17:30:35,994 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2024-01-03 17:30:35,994 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2024-01-03 17:30:35,995 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2024-01-03 17:30:35,995 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2024-01-03 17:30:35,996 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2024-01-03 17:30:35,996 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2024-01-03 17:30:35,998 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2024-01-03 17:30:35,998 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2024-01-03 17:30:35,998 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2024-01-03 17:30:35,999 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_flat_0785.fits'.
# 2024-01-03 17:30:36,000 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2024-01-03 17:30:36,000 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 
- stpipe.Image2Pipeline.assign_wcs - INFO - Saved model in ./stage2/assign_wcs/jw01837014001_02101_00002_mirimage_assign_wcs.fits
# 2024-01-03 17:30:41,320 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2024-01-03 17:30:41,460 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw01837014001_02101_00002_mirimage_assign_wcs.fits>,).
# 2024-01-03 17:30:41,462 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/flatfield/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2024-01-03 17:30:41,559 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:41,559 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:41,560 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:41,562 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:41,565 - stpipe.Image2Pipeline.flat_field - INFO - Using FLAT reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_flat_0785.fits
# 2024-01-03 17:30:41,565 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2024-01-03 17:30:41,566 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2024-01-03 17:30:41,566 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2024-01-03 17:30:41,860 - stpipe.Image2Pipeline.flat_field - INFO - Saved model in ./stage2/flatfield/jw01837014001_02101_00002_mirimage_flat_field.fits
# 2024-01-03 17:30:41,860 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2024-01-03 17:30:42,000 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw01837014001_02101_00002_mirimage_flat_field.fits>,).
# 2024-01-03 17:30:42,002 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/photom/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}
# 2024-01-03 17:30:42,027 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_photom_0174.fits
# 2024-01-03 17:30:42,028 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_area_0004.fits
# 2024-01-03 17:30:42,105 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2024-01-03 17:30:42,105 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2024-01-03 17:30:42,106 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2024-01-03 17:30:42,106 - stpipe.Image2Pipeline.photom - INFO -  filter: F770W
# 2024-01-03 17:30:42,162 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2024-01-03 17:30:42,164 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2024-01-03 17:30:42,165 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 0.25882
# 2024-01-03 17:30:42,362 - stpipe.Image2Pipeline.photom - INFO - Saved model in ./stage2/photom/jw01837014001_02101_00002_mirimage_photom.fits
# 2024-01-03 17:30:42,363 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2024-01-03 17:30:42,504 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from jw01837014001_02101_00002_mirimage_photom.fits>,).
# 2024-01-03 17:30:42,506 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/resample/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': False, 'allowed_memory': None, 'in_memory': True}
# 2024-01-03 17:30:42,537 - stpipe.Image2Pipeline.resample - INFO - Using drizpars reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2024-01-03 17:30:42,559 - stpipe.Image2Pipeline.resample - INFO - Driz parameter kernel: square
# 2024-01-03 17:30:42,559 - stpipe.Image2Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2024-01-03 17:30:42,560 - stpipe.Image2Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2024-01-03 17:30:42,560 - stpipe.Image2Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2024-01-03 17:30:42,560 - stpipe.Image2Pipeline.resample - INFO - Output pixel scale ratio: 1.0
# 2024-01-03 17:30:42,692 - stpipe.Image2Pipeline.resample - INFO - Resampling science data
# 2024-01-03 17:30:43,059 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:30:43,272 - stpipe.Image2Pipeline.resample - INFO - Resampling var_rnoise
# 2024-01-03 17:30:43,669 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:30:43,890 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2024-01-03 17:30:44,260 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:30:44,480 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2024-01-03 17:30:44,848 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:30:45,100 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  34.361422691 -5.266644833 34.330576348 -5.273155296 34.337178201 -5.304172815 34.368026020 -5.297662026
# 2024-01-03 17:30:45,239 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./stage2/resample/jw01837014001_02101_00002_mirimage_i2d.fits
# 2024-01-03 17:30:45,240 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2024-01-03 17:30:45,241 - stpipe.Image2Pipeline - INFO - Finished processing product ./stage2/jw01837014001_02101_00002_mirimage
# 2024-01-03 17:30:45,242 - stpipe.Image2Pipeline - INFO - Processing product ./stage2/jw01837014001_04101_00001_mirimage
# 2024-01-03 17:30:45,243 - stpipe.Image2Pipeline - INFO - Working on input ./stage2/jw01837014001_04101_00001_mirimage_rate.fits ...
# 2024-01-03 17:30:45,434 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from jw01837014001_04101_00001_mirimage_rate.fits>,).
# 2024-01-03 17:30:45,435 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/assign_wcs/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2024-01-03 17:30:45,635 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/data/public/jwst_crds/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/data/public/jwst_crds/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2024-01-03 17:30:45,708 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  34.361284483 -5.267173524 34.330574566 -5.273770652 34.337186272 -5.304491806 34.368008735 -5.298167446
# 2024-01-03 17:30:45,709 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  34.361284483 -5.267173524 34.330574566 -5.273770652 34.337186272 -5.304491806 34.368008735 -5.298167446
# 2024-01-03 17:30:45,710 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2024-01-03 17:30:45,930 - stpipe.Image2Pipeline.assign_wcs - INFO - Saved model in ./stage2/assign_wcs/jw01837014001_04101_00001_mirimage_assign_wcs.fits
# 2024-01-03 17:30:45,931 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2024-01-03 17:30:46,091 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw01837014001_04101_00001_mirimage_assign_wcs.fits>,).
# 2024-01-03 17:30:46,093 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/flatfield/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2024-01-03 17:30:46,190 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:46,191 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:46,191 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:46,193 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-01-03 17:30:46,196 - stpipe.Image2Pipeline.flat_field - INFO - Using FLAT reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_flat_0785.fits
# 2024-01-03 17:30:46,196 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2024-01-03 17:30:46,196 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2024-01-03 17:30:46,197 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2024-01-03 17:30:46,488 - stpipe.Image2Pipeline.flat_field - INFO - Saved model in ./stage2/flatfield/jw01837014001_04101_00001_mirimage_flat_field.fits
# 2024-01-03 17:30:46,488 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2024-01-03 17:30:46,672 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw01837014001_04101_00001_mirimage_flat_field.fits>,).
# 2024-01-03 17:30:46,674 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/photom/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}
# 2024-01-03 17:30:46,700 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_photom_0174.fits
# 2024-01-03 17:30:46,701 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_area_0004.fits
# 2024-01-03 17:30:46,777 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2024-01-03 17:30:46,778 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2024-01-03 17:30:46,778 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2024-01-03 17:30:46,778 - stpipe.Image2Pipeline.photom - INFO -  filter: F770W
# 2024-01-03 17:30:46,833 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2024-01-03 17:30:46,835 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2024-01-03 17:30:46,836 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 0.25882
# 2024-01-03 17:30:47,033 - stpipe.Image2Pipeline.photom - INFO - Saved model in ./stage2/photom/jw01837014001_04101_00001_mirimage_photom.fits
# 2024-01-03 17:30:47,034 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2024-01-03 17:30:47,215 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from jw01837014001_04101_00001_mirimage_photom.fits>,).
# 2024-01-03 17:30:47,217 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/resample/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': False, 'allowed_memory': None, 'in_memory': True}
# 2024-01-03 17:30:47,248 - stpipe.Image2Pipeline.resample - INFO - Using drizpars reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2024-01-03 17:30:47,270 - stpipe.Image2Pipeline.resample - INFO - Driz parameter kernel: square
# 2024-01-03 17
- stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2024-01-03 17:30:55,388 - stpipe.Image2Pipeline.assign_wcs - INFO - Saved model in ./stage2/assign_wcs/jw01837014001_06101_00001_mirimage_assign_wcs.fits
# 2024-01-03 17:30:55,389 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2024-01-03 17:30:55,540 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw01837014001_06101_00001_mirimage_assign_wcs.fits>,).
# 2024-01-03 17:30:55,541 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/flatfield/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2024-01-03 17:30:55,630 - stpipe.Image2Pipeline.flat_field - INFO - Using FLAT reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_flat_0792.fits
# 2024-01-03 17:30:55,630 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2024-01-03 17:30:55,631 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2024-01-03 17:30:55,631 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2024-01-03 17:30:55,929 - stpipe.Image2Pipeline.flat_field - INFO - Saved model in ./stage2/flatfield/jw01837014001_06101_00001_mirimage_flat_field.fits
# 2024-01-03 17:30:55,930 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2024-01-03 17:30:56,079 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw01837014001_06101_00001_mirimage_flat_field.fits>,).
# 2024-01-03 17:30:56,081 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/photom/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}
# 2024-01-03 17:30:56,106 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_photom_0174.fits
# 2024-01-03 17:30:56,107 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_area_0004.fits
# 2024-01-03 17:30:56,184 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2024-01-03 17:30:56,184 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2024-01-03 17:30:56,184 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2024-01-03 17:30:56,185 - stpipe.Image2Pipeline.photom - INFO -  filter: F1800W
# 2024-01-03 17:30:56,240 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2024-01-03 17:30:56,242 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# ...
# 2024-01-03 17:32:22,688 - stpipe.Image2Pipeline.resample - INFO - Using drizpars reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2024-01-03 17:32:22,711 - stpipe.Image2Pipeline.resample - INFO - Driz parameter kernel: square
# 2024-01-03 17:32:22,711 - stpipe.Image2Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2024-01-03 17:32:22,712 - stpipe.Image2Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2024-01-03 17:32:22,712 - stpipe.Image2Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2024-01-03 17:32:22,712 - stpipe.Image2Pipeline.resample - INFO - Output pixel scale ratio: 1.0
# 2024-01-03 17:32:22,846 - stpipe.Image2Pipeline.resample - INFO - Resampling science data
# 2024-01-03 17:32:23,266 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:32:23,478 - stpipe.Image2Pipeline.resample - INFO - Resampling var_rnoise
# 2024-01-03 17:32:23,896 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:32:24,117 - stpipe.Image2Pipeline.resample - INFO - Resampling var_poisson
# 2024-01-03 17:32:24,530 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:32:24,750 - stpipe.Image2Pipeline.resample - INFO - Resampling var_flat
# 2024-01-03 17:32:25,166 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1019, 1029)
# 2024-01-03 17:32:25,419 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  34.356480354 -5.247417568 34.325546620 -5.253498142 34.331712302 -5.284604502 34.362647524 -5.278523624
# 2024-01-03 17:32:25,561 - stpipe.Image2Pipeline.resample - INFO - Saved model in ./stage2/resample/jw01837023001_08101_00001_mirimage_i2d.fits
# 2024-01-03 17:32:25,562 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2024-01-03 17:32:25,563 - stpipe.Image2Pipeline - INFO - Finished processing product ./stage2/jw01837023001_08101_00001_mirimage
# 2024-01-03 17:32:25,564 - stpipe.Image2Pipeline - INFO - Processing product ./stage2/jw01837023001_08101_00002_mirimage
# 2024-01-03 17:32:25,565 - stpipe.Image2Pipeline - INFO - Working on input ./stage2/jw01837023001_08101_00002_mirimage_rate.fits ...
# 2024-01-03 17:32:25,784 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from jw01837023001_08101_00002_mirimage_rate.fits>,).
# 2024-01-03 17:32:25,785 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/assign_wcs/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2024-01-03 17:32:25,985 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/data/public/jwst_crds/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/data/public/jwst_crds/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2024-01-03 17:32:26,066 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  34.356360787 -5.246973741 34.325562579 -5.253142457 34.331742439 -5.283952880 34.362648890 -5.278058186
# 2024-01-03 17:32:26,067 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  34.356360787 -5.246973741 34.325562579 -5.253142457 34.331742439 -5.283952880 34.362648890 -5.278058186
# 2024-01-03 17:32:26,067 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2024-01-03 17:32:26,289 - stpipe.Image2Pipeline.assign_wcs - INFO - Saved model in ./stage2/assign_wcs/jw01837023001_08101_00002_mirimage_assign_wcs.fits
# 2024-01-03 17:32:26,290 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2024-01-03 17:32:26,475 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw01837023001_08101_00002_mirimage_assign_wcs.fits>,).
# 2024-01-03 17:32:26,476 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage2/flatfield/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2024-01-03 17:32:26,565 - stpipe.Image2Pipeline.flat_field - INFO - Using FLAT reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_flat_0792.fits
# 2024-01-03 17:32:26,566 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2024-01-03 17:32:26,566 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2024-01-03 17:32:26,566 - stpipe.Image2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2024-01-03 17:32:26,869 - stpipe.Image2Pipeline.flat_field - INFO - Saved model in ./stage2/flatfield/jw01837023001_08101_00002_mirimage_flat_field.fits
# 2024-01-03 17:32:26,870 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2024-01-03 17:32:27,039 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from j
- stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_02101_00002_mirimage_cal.fits
# 2024-01-03 17:32:34,042 - stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_04101_00001_mirimage_cal.fits
# 2024-01-03 17:32:34,221 - stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_04101_00002_mirimage_cal.fits
# 2024-01-03 17:32:34,399 - stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_06101_00001_mirimage_cal.fits
# 2024-01-03 17:32:34,578 - stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_06101_00002_mirimage_cal.fits
# 2024-01-03 17:32:34,757 - stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_08101_00001_mirimage_cal.fits
# 2024-01-03 17:32:34,934 - stpipe.Image2Pipeline - INFO - Saved model in ./stage2/jw01837023001_08101_00002_mirimage_cal.fits
# 2024-01-03 17:32:34,935 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
os.system('rm '+output_dir+'*_rate.fits')
# Out:
# 0

# %% [markdown]
# ## Stage 2.5
#
# Destriping and background subtraction

# %%
from astroscrappy import detect_cosmics
import sep
from astropy.convolution import Tophat2DKernel
from scipy.ndimage import binary_dilation
import numpy as np
from astropy.table import Table
import pyregion
from astropy.stats import sigma_clipped_stats

def get_glob_bkg(dat, err):
    mask = (np.isfinite(err)==False)
    mask[:,:300]=True
    mask[:,1026:]=True
    ok = (mask==False)
    med_global = np.nanmedian(dat.astype('float')[ok])
    return med_global

def rm_strip(cal_file, rm_hz=False, rm_vt=False):
    with datamodels.open(cal_file) as dm:
        # Read science image and build weight
        sci_img = dm.data.copy()
        err_map = dm.err.copy()
        #wht = build_driz_weight(dm, weight_type='ivm', good_bits='~DO_NOT_USE+NON_SCIENCE')
        #mask = (wht==0)
        # Mask bad pixels
        mask = (np.isfinite(err_map)==False) | (dm.dq>4)
        err_map[mask] = np.inf
        # Get the global bkg values
        glob_bkg = get_glob_bkg(sci_img, err_map)
        # Subtract horizontal stripping
        if rm_hz:
            hz_strips = sigma_clipped_stats(sci_img, mask=mask, sigma=2, maxiters=None, cenfunc='median', stdfunc='std', axis=1)[1]
            sci_img = (sci_img.T-hz_strips).T
        # Subract vertical stripping
        if rm_vt:
            vt_strips = sigma_clipped_stats(sci_img, mask=mask, sigma=2, maxiters=None, cenfunc='median', stdfunc='std', axis=0)[1]
            sci_img -= vt_strips
        # If not horizontal nor vertical, subtract a constant global background
        if (rm_hz or rm_vt)==False:
            sci_img -= glob_bkg
        else:
            # Set all nan (may be caused by strip removal)
            mask[np.isnan(sci_img)] = True
            sci_img[np.isnan(sci_img)] = 0
            err_map[mask] = np.inf
        # Replace the old data
        dm.data = sci_img
        #dm.err = err_map
        dm.save(cal_file.replace('.fits','')+'_stprm.fits', overwrite=True)
    return glob_bkg

def det_src(img, sigma_threshold=2, bw=72, bh=72, fw=5, fh=5,
            clean_edge=True, cr_sigclip=1., minarea=5, r_dilate=-1,
            kernel=np.array([[1,2,1], [2,4,2], [1,2,1]])):
    # mask_threshold=0.3, no longer used
    # Open data model
    #with datamodels.open(img) as dm:
        # Read science image and build weight
        #dat = dm.data.copy()
        #wht = build_driz_weight(dm, weight_type='ivm', good_bits='~DO_NOT_USE+NON_SCIENCE')
        # subtract a constant background first 
        # This is no longer needed becuase we remove the stripes before
        #dat -= get_glob_bkg(dat, dm.err)
    
    # Check input type
    if type(img) == str:
        # Read data
        dat = fits.getdata(img, 'sci')
        err = fits.getdata(img, 'err')
        dq = fits.getdata(img, 'dq')
    elif type(img) == jwst.datamodels.ImageModel:
        dat = img.data.copy()
        err = img.err.copy()
        dq = img.dq.copy()
    # Mask cosmic rays
    cr_map = detect_cosmics(dat, sigclip=cr_sigclip)[0]*1
    err[np.where(cr_map)] = np.inf
    err[dq>4] = np.inf
    # subtract a background, then find objects.     
    #mask = (wht < np.max(wht)* mask_threshold) 
    wht = 1./err**2
    mask = (np.isfinite(err)==False)
    wht[mask] = np.nan
    wht /= np.nanmedian(wht)
    # Estimate a spatial dependent background
    bkg = sep.Background(dat.astype('float'), mask=mask, bw=bw, bh=bh, fw=fw, fh=fh)
    bkg.back()[mask] = np.nan
    # identify objects
    wdat = (dat-bkg.back())  * wht
    wdat[mask] = np.nan
    wbkg = sep.Background(wdat, mask=mask, bw=bw, bh=bh, fw=fw, fh=fh)  
    objects = sep.extract(wdat, sigma_threshold, mask=mask, filter_kernel=kernel,
                          err=wbkg.globalrms, segmentation_map=True, minarea=minarea)
    src, seg = objects[0], objects[1]
    # Convert src to astropy table format
    src = Table(src)
    # Add an ID column 
    src.add_column( np.arange(len(src))+1, name='id' )
    # Clean sources close to detector edge if needed
    if clean_edge: 
        # Read the bad master region file
        regs = pyregion.open("../data/master_noisy_region.reg")
        # Iterate over each bad region
        bad_src_idxs = []
        for reg in regs:
            # Get the four points
            x1, x2 = reg.coord_list[0]-reg.coord_list[2]/2, reg.coord_list[0]+reg.coord_list[2]/2
            y1, y2 = reg.coord_list[1]-reg.coord_list[3]/2, reg.coord_list[1]+reg.coord_list[3]/2
            # Get sources in the region
            bad_src_idxs = np.append(bad_src_idxs,
                    np.where( (src['x']>x1) & (src['x']<x2) & (src['y']>y1) & (src['y']<y2) )[0] )
        bad_src_idxs = np.sort(np.unique(bad_src_idxs)).astype(int)
        # Remove the bad sources in both catalog and segmentaion
        good_src_idxs = np.delete(np.arange(len(src)), bad_src_idxs)
        src = src[good_src_idxs]
        for bad_id in bad_src_idxs+1:
            seg[seg==bad_id] = 0
    # Dilate the segmentaion? (but all pixel will be set to 1)
    if r_dilate>0:
        footprint = Tophat2DKernel(radius=r_dilate)
        seg = binary_dilation(seg, footprint.array).astype(int)
            
    return src, dat, wht, bkg, seg

def super_bg(files, sigma_threshold=2, bw=72, bh=72, fw=5, fh=5, minarea=20,
             kernel=np.array([[1,2,1], [2,4,2], [1,2,1]]), r_dilate=10,
             clean_edge=True, write_bg=False):
    # read in each image.  Identify objects and mask with background from SEP
    x, y = np.shape( fits.getdata(files[0]) )
    darr = np.zeros( [len(files), x, y] )
    # Check number of files 
    if len(files)<2:
        raise Exception("Too few input files?!")
    elif len(files)==2:
        print('Warning: building master background from a single file')
        # Use different parameters if building from a single image
        clean_edge = False
        r_dilate = -1
        minarea = 5
        sigma_threshold = 1.2
    else:
        print('Building master background from a %d files' %(len(files)-1))
    # Iterate over each file to get the background     
    for i,f in enumerate(files):
        # Detect sources 
        src, dat, wht, bkg, seg = det_src(f, sigma_threshold=sigma_threshold,
            r_dilate=r_dilate, bw=bw, bh=bh, fw=fw, fh=fh, cr_sigclip=1.,
            minarea=minarea, kernel=kernel, clean_edge=clean_edge)
        print("%d src detected!" %len(src))
        # Fill in NaN or bkg, depending on number of files available
        if len(files)>2:
            dat[seg > 0] = np.nan
        else:
            dat[seg > 0] = bkg.back()[seg > 0]        
        # Save the data
        darr[i] = dat
    # Subtract background for each file
    for idx0, f0 in enumerate(files):
        #take median 
        oth_idxs = np.delete(range(len(files)), idx0)
        dmed = np.nanmedian(darr[oth_idxs], axis=0)
        # Set nan to 0 to avoid NaN in the result
        # dmed[np.isnan( dmed )] = 0
        # subtract and writeout
        with fits.open(f0) as hdu:
            # Subtract the background
            hdu['sci'].data -= dmed
            mask = (np.isfinite(hdu['err'].data)==False) | np.isnan(hdu['sci'].data) | hdu['dq'].data>4
            hdu['sci'].data[mask] = 0
            hdu['err'].data[mask] = np.inf
            hdu.writeto( f0.replace('.fits','')+'_bgsub.fits', overwrite=True)
            # Write background if needed
            if write_bg: 
                hdu['sci'].data = dmed
                hdu.writeto( f0.replace('.fits','')+'_bg.fits', overwrite=True)
        print(f0.replace('.fits','')+'_bgsub.fits' + "  Done!")
    
    return

# %%
def group_imgs(all_files, prop):
    # Adapted from CEERS MIRI notebook https://github.com/ceers/ceers-miri
    # Extract the needed property for each file
    prop_strs = []
    for f in all_files:
        hd = fits.getheader(f)
        # print proposal id
        print(f, hd['PROGRAM'], hd['TARGPROP'], hd['FILTER'], hd['READPATT'], hd['EFFEXPTM'])
        if prop=="band":
            prop_strs.append( hd['FILTER'] )
        elif prop=="field":
            prop_strs.append( hd['TARGPROP'] )
        elif prop=="field_band":
            prop_strs.append( hd['TARGPROP'] + '_' + hd['FILTER'] )
        elif prop=='propid_band_exp':
            prop_strs.append( str(hd['PROGRAM']) + '_' + hd['FILTER'] + '_' + f"{hd['EFFEXPTM']:.0f}s" )
        else:
            ValueError("prop unknown")

    # Group the files 
    groups = {}
    unq_prop_strs = list(set(prop_strs))
    for prop_str in unq_prop_strs:
        group = []
        # Find the files with the prop_str
        for file_idx, buf in enumerate(prop_strs):
            if buf==prop_str: group.append( all_files[file_idx] )
        groups[prop_str] = group
        
    return groups

# %%
output_dir = './stage2.5/'
os.makedirs(output_dir, exist_ok=True)

input_dir='./stage2/'
os.system('cp '+input_dir+'*_cal.fits '+output_dir+'')
list_files=glob.glob(output_dir+'*_cal.fits')

# %%
for file in list_files:
    # Run the strip removal 
    rm_strip(file, rm_hz=True, rm_vt=True)
# Out:
# 2024-01-03 21:14:13,661 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:13,662 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:13,714 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:14,206 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:14,206 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:14,257 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:14,744 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:14,745 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:14,796 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:15,379 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:15,380 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:15,432 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:15,922 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:15,922 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:15,973 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:16,466 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:16,467 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:16,518 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:17,012 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:17,013 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:17,064 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:17,651 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:17,652 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:17,704 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:18,194 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:18,195 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:18,246 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:18,739 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:18,740 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:18,792 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:19,285 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:19,286 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:19,338 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:19,826 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:19,827 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:19,879 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:20,465 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:20,465 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:20,517 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:21,004 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:21,006 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:21,057 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:21,542 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:21,543 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14:21,594 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2024-01-03 21:14:22,081 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/astropy/stats/sigma_clipping.py:1030: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(data_clipped, axis=axis)
#
# 2024-01-03 21:14:22,082 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
#
# 2024-01-03 21:14
00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01727092001_02201_00003_mirimage_cal_stprm.fits',
#   './stage2.5/jw01727092001_02201_00004_mirimage_cal_stprm.fits',
#   './stage2.5/jw01727092001_04201_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01727092001_04201_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01727092001_04201_00003_mirimage_cal_stprm.fits',
#   './stage2.5/jw01727092001_04201_00004_mirimage_cal_stprm.fits'],
#  '01837_F1800W_447s': ['./stage2.5/jw01837014001_06101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837014001_06101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837014001_08101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837014001_08101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837022001_06101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837022001_06101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837022001_08101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837022001_08101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837023001_06101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837023001_06101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837023001_08101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837023001_08101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837028001_06101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837028001_06101_00002_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837028001_08101_00001_mirimage_cal_stprm.fits',
#   './stage2.5/jw01837028001_08101_00002_mirimage_cal_stprm.fits']}

# %%
# Subtract super background
for group_name, group_files in groups.items():
    print(group_name, group_files)
    print(f"processing {len(group_files)} files for sky subtraction of {group_name}") 
    super_bg(group_files, write_bg=True, clean_edge=False)
# Out:
# 01837_F770W_444s ['./stage2.5/jw01837014001_02101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837014001_02101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837014001_04101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837014001_04101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_02101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_02101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_04101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_04101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_02101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_02101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_04101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_04101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_02101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_04101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_04101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_02101_00002_mirimage_cal_stprm.fits']
# processing 16 files for sky subtraction of 01837_F770W_444s
# Building master background from a 15 files
# 42 src detected!
# 41 src detected!
# 42 src detected!
# 42 src detected!
# 30 src detected!
# 27 src detected!
# 28 src detected!
# 27 src detected!
# 42 src detected!
# 43 src detected!
# 43 src detected!
# 41 src detected!
# 63 src detected!
# 66 src detected!
# 69 src detected!
# 69 src detected!
# ./stage2.5/jw01837014001_02101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837014001_02101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837014001_04101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837014001_04101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_02101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_02101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_04101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_04101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_02101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_02101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_04101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_04101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_02101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_04101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_04101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_02101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# 01727_F770W_253s ['./stage2.5/jw01727090001_02201_00001_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_02201_00002_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_02201_00003_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_02201_00004_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_04201_00001_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_04201_00002_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_04201_00003_mirimage_cal_stprm.fits', './stage2.5/jw01727090001_04201_00004_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_02201_00001_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_02201_00002_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_02201_00003_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_02201_00004_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_04201_00001_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_04201_00002_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_04201_00003_mirimage_cal_stprm.fits', './stage2.5/jw01727092001_04201_00004_mirimage_cal_stprm.fits']
# processing 16 files for sky subtraction of 01727_F770W_253s
# Building master background from a 15 files
# 75 src detected!
# 75 src detected!
# 75 src detected!
# 75 src detected!
# 73 src detected!
# 78 src detected!
# 75 src detected!
# 76 src detected!
# 62 src detected!
# 58 src detected!
# 76 src detected!
# 81 src detected!
# 61 src detected!
# 60 src detected!
# 75 src detected!
# 80 src detected!
# ./stage2.5/jw01727090001_02201_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_02201_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_02201_00003_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_02201_00004_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_04201_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_04201_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_04201_00003_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727090001_04201_00004_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_02201_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_02201_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_02201_00003_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_02201_00004_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_04201_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_04201_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_04201_00003_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01727092001_04201_00004_mirimage_cal_stprm_bgsub.fits  Done!
# 01837_F1800W_447s ['./stage2.5/jw01837014001_06101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837014001_06101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837014001_08101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837014001_08101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_06101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_06101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_08101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837022001_08101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_06101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_06101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_08101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837023001_08101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_06101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_06101_00002_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_08101_00001_mirimage_cal_stprm.fits', './stage2.5/jw01837028001_08101_00002_mirimage_cal_stprm.fits']
# processing 16 files for sky subtraction of 01837_F1800W_447s
# Building master background from a 15 files
# 30 src detected!
# 26 src detected!
# 27 src detected!
# 29 src detected!
# 20 src detected!
# 21 src detected!
# 21 src detected!
# 21 src detected!
# 20 src detected!
# 22 src detected!
# 22 src detected!
# 18 src detected!
# 37 src detected!
# 35 src detected!
# 37 src detected!
# 34 src detected!
# 2024-01-03 20:30:37,454 - stpipe - WARNING - /tmp/ipykernel_794274/1658824691.py:161: RuntimeWarning: All-NaN slice encountered
#   dmed = np.nanmedian(darr[oth_idxs], axis=0)
# ./stage2.5/jw01837014001_06101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837014001_06101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837014001_08101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837014001_08101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_06101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_06101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_08101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837022001_08101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_06101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_06101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_08101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837023001_08101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_06101_00002_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_08101_00001_mirimage_cal_stprm_bgsub.fits  Done!
# ./stage2.5/jw01837028001_08101_00002_mirimage_cal_stprm_bgsub.fits  Done!

# %% [markdown]
# ## Stage 3

# %%
# The entire calwebb_image3 pipeline
from jwst.pipeline import calwebb_image3

# Individual steps that make up calwebb_image3
from jwst.tweakreg import TweakRegStep
from jwst.skymatch import SkyMatchStep
from jwst.outlier_detection import OutlierDetectionStep
from jwst.resample import ResampleStep
from jwst.source_catalog import SourceCatalogStep
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# %%
output_dir = './stage3/'
output_dir_tweakreg = output_dir+'tweakreg/'
output_dir_skymatch = output_dir+'skymatch/'
output_dir_outlier_detection = output_dir+'outlier_detection/'
output_dir_resample = output_dir+'resample/'
output_dir_source_catalog = output_dir+'source_catalog/'

os.makedirs(output_dir, exist_ok=True)
os.makedirs(output_dir_tweakreg, exist_ok=True)
os.makedirs(output_dir_skymatch, exist_ok=True)
os.makedirs(output_dir_outlier_detection, exist_ok=True)
os.makedirs(output_dir_resample, exist_ok=True)
os.makedirs(output_dir_source_catalog, exist_ok=True)

# %%
input_dir='./stage2.5/'
os.system('cp '+input_dir+'*_cal_stprm_bgsub.fits '+output_dir+'')
# Out:
# 0

# %%
file_list_cal_stprm_bgsub = glob.glob(output_dir+'*_cal_stprm_bgsub.fits')
level3_groups = group_imgs(file_list_cal_stprm_bgsub, 'field_band')
level3_groups
# Out:
# ./stage3/jw01837014001_02101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F770W FASTR1 444.006
# ./stage3/jw01837014001_02101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F770W FASTR1 444.006
# ./stage3/jw01837014001_04101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F770W FASTR1 444.006
# ./stage3/jw01837014001_04101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F770W FASTR1 444.006
# ./stage3/jw01837014001_06101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F1800W FASTR1 446.781
# ./stage3/jw01837014001_06101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F1800W FASTR1 446.781
# ./stage3/jw01837014001_08101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F1800W FASTR1 446.781
# ./stage3/jw01837014001_08101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-6 F1800W FASTR1 446.781
# ./stage3/jw01837022001_02101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F770W FASTR1 444.006
# ./stage3/jw01837022001_02101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F770W FASTR1 444.006
# ./stage3/jw01837022001_04101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F770W FASTR1 444.006
# ./stage3/jw01837022001_04101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F770W FASTR1 444.006
# ./stage3/jw01837022001_06101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F1800W FASTR1 446.781
# ./stage3/jw01837022001_06101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F1800W FASTR1 446.781
# ./stage3/jw01837022001_08101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F1800W FASTR1 446.781
# ./stage3/jw01837022001_08101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-22 F1800W FASTR1 446.781
# ./stage3/jw01837023001_02101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837023001_02101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837023001_04101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837023001_04101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837023001_06101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837023001_06101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837023001_08101_00001_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837023001_08101_00002_mirimage_cal_stprm_bgsub.fits 01837 UDS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837028001_02101_00001_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837028001_02101_00002_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837028001_04101_00001_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837028001_04101_00002_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F770W FASTR1 444.006
# ./stage3/jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837028001_06101_00002_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837028001_08101_00001_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01837028001_08101_00002_mirimage_cal_stprm_bgsub.fits 01837 COSMOS-2-TILE-7 F1800W FASTR1 446.781
# ./stage3/jw01727090001_02201_00001_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_02201_00002_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_02201_00003_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_02201_00004_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_04201_00001_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_04201_00002_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_04201_00003_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727090001_04201_00004_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-6 F770W FASTR1 252.529
# ./stage3/jw01727092001_02201_00001_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_02201_00002_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_02201_00003_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_02201_00004_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_04201_00001_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_04201_00002_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_04201_00003_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# ./stage3/jw01727092001_04201_00004_mirimage_cal_stprm_bgsub.fits 01727 CWEBTILE-5-7 F770W FASTR1 252.529
# {'UDS-2-TILE-7_F770W': ['./stage3/jw01837023001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-6_F770W': ['./stage3/jw01837014001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-22_F770W': ['./stage3/jw01837022001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-6_F1800W': ['./stage3/jw01837014001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-22_F1800W': ['./stage3/jw01837022001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'COSMOS-2-TILE-7_F770W': ['./stage3/jw01837028001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'COSMOS-2-TILE-7_F1800W': ['./stage3/jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'CWEBTILE-5-6_F770W': ['./stage3/jw01727090001_02201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00004_mirimage_cal_stprm_bgsub.fits'],
#  'CWEBTILE-5-7_F770W': ['./stage3/jw01727092001_02201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00004_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-7_F1800W': ['./stage3/jw01837023001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_08101_00002_mirimage_cal_stprm_bgsub.fits']}

# %%
def merge_group(groups, group_name_list, new_group_name):
    # Merge a list of groups into a new group
    # Get the files
    files = []
    for group_name in group_name_list:
        files.extend( level3_groups[group_name] )
    # Add to the level3_groups
    level3_groups[new_group_name] = files
    return 

merge_group(level3_groups, ['CWEBTILE-5-7_F770W', 'COSMOS-2-TILE-7_F770W', 'CWEBTILE-5-6_F770W'], 'CosmicOwl_F770W')
merge_group(level3_groups, ['COSMOS-2-TILE-7_F1800W'], 'CosmicOwl_F1800W')

level3_groups
# Out:
# {'UDS-2-TILE-7_F770W': ['./stage3/jw01837023001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-6_F770W': ['./stage3/jw01837014001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-22_F770W': ['./stage3/jw01837022001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-6_F1800W': ['./stage3/jw01837014001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837014001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-22_F1800W': ['./stage3/jw01837022001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837022001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'COSMOS-2-TILE-7_F770W': ['./stage3/jw01837028001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_04101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'COSMOS-2-TILE-7_F1800W': ['./stage3/jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'CWEBTILE-5-6_F770W': ['./stage3/jw01727090001_02201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00004_mirimage_cal_stprm_bgsub.fits'],
#  'CWEBTILE-5-7_F770W': ['./stage3/jw01727092001_02201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00004_mirimage_cal_stprm_bgsub.fits'],
#  'UDS-2-TILE-7_F1800W': ['./stage3/jw01837023001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837023001_08101_00002_mirimage_cal_stprm_bgsub.fits'],
#  'CosmicOwl_F770W': ['./stage3/jw01727092001_02201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_02201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727092001_04201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_02101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_02101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_04101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_04101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_02201_00004_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00003_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01727090001_04201_00004_mirimage_cal_stprm_bgsub.fits'],
#  'CosmicOwl_F1800W': ['./stage3/jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_06101_00002_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_08101_00001_mirimage_cal_stprm_bgsub.fits',
#   './stage3/jw01837028001_08101_00002_mirimage_cal_stprm_bgsub.fits']}

# %%
# Create and open the association file and load into json object
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3 import Asn_Lv3Image

group = 'CosmicOwl_F770W'
asn = asn_from_list.asn_from_list(level3_groups[group], rule=Asn_Lv3Image, 
                product_name=group, asn_type="image3")
asn_file_path = f'{group}_level3_asn.json'
with open(asn_file_path, 'w') as outfile:
    name, serialized = asn.dump(format='json')
    outfile.write(serialized)


#If some parameters are known to have better results with certain value use the dictionary
parameter_dict = {"tweakreg": {"snr_threshold": 3.0, "brightest": 1000, "separation":0.1, "searchrad":1, "tolerance":0.5, "abs_minobj":4, "expand_refcat":True, "output_dir": output_dir_tweakreg,"save_results": True,"abs_refcat":'GAIADR3'}, #kernel_fwhm can also be added for better centroiding
                  "skymatch": {"skip":False,"skymethod":'local',"output_dir": output_dir_skymatch,"save_results": True,"subtract":True,"match_down":True},
                  "outlier_detection": {'snr': '3.0 2.0', 'scale': '0.4 0.3', "output_dir": output_dir_outlier_detection,"save_results": True},
                  "resample": {"pixfrac": 0.8,"pixel_scale":0.1,"rotation":0,"output_dir": output_dir_resample,"save_results": True}, #pixfrac can be higher if one wants lesser resolution
                  "source_catalog": {"snr_threshold": 5.0,"output_dir": output_dir_source_catalog,"save_results": True}, 
                 }

call_output = calwebb_image3.Image3Pipeline.call(asn_file_path, output_dir=output_dir, save_results=True, steps=parameter_dict,logcfg='stage3-log.cfg')
# Out:
# 2024-01-03 21:14:42,332 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)

# %%
group = 'CosmicOwl_F1800W'
asn = asn_from_list.asn_from_list(level3_groups[group], rule=Asn_Lv3Image, 
                product_name=group, asn_type="image3")
asn_file_path = f'{group}_level3_asn.json'
with open(asn_file_path, 'w') as outfile:
    name, serialized = asn.dump(format='json')
    outfile.write(serialized)


#If some parameters are known to have better results with certain value use the dictionary
parameter_dict = {"tweakreg": {"snr_threshold": 3.0, "brightest": 1000, "separation":0.1, "searchrad":1, "tolerance":0.5, "abs_minobj":4, "expand_refcat":True, "output_dir": output_dir_tweakreg,"save_results": True,"abs_refcat":'GAIADR3'}, #kernel_fwhm can also be added for better centroiding
                  "skymatch": {"skip":False,"skymethod":'local',"output_dir": output_dir_skymatch,"save_results": True,"subtract":True,"match_down":True},
                  "outlier_detection": {'snr': '3.0 2.0', 'scale': '0.4 0.3', "output_dir": output_dir_outlier_detection,"save_results": True},
                  "resample": {"pixfrac": 0.8,"pixel_scale":0.1,"rotation":0,"output_dir": output_dir_resample,"save_results": True}, #pixfrac can be higher if one wants lesser resolution
                  "source_catalog": {"snr_threshold": 5.0,"output_dir": output_dir_source_catalog,"save_results": True}, 
                 }

call_output = calwebb_image3.Image3Pipeline.call(asn_file_path, output_dir=output_dir, save_results=True, steps=parameter_dict,logcfg='stage3-log.cfg')
# Out:
# 2024-01-03 22:34:38,775 - stpipe - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-01-03 22:34:38,925 - stpipe - INFO - PARS-TWEAKREGSTEP parameters found: /data/public/jwst_crds/references/jwst/miri/jwst_miri_pars-tweakregstep_0015.asdf
# 2024-01-03 22:34:38,938 - stpipe - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /data/public/jwst_crds/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0036.asdf
# 2024-01-03 22:34:38,949 - stpipe - INFO - PARS-SOURCECATALOGSTEP parameters found: /data/public/jwst_crds/references/jwst/miri/jwst_miri_pars-sourcecatalogstep_0016.asdf
# 2024-01-03 22:34:38,966 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2024-01-03 22:34:38,967 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2024-01-03 22:34:38,969 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2024-01-03 22:34:38,970 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2024-01-03 22:34:38,972 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2024-01-03 22:34:38,973 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2024-01-03 22:34:38,974 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2024-01-03 22:34:39,164 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('CosmicOwl_F1800W_level3_asn.json',).
# 2024-01-03 22:34:39,170 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/tweakreg/', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'use_custom_catalogs': False, 'catalog_format': 'ecsv', 'catfile': '', 'kernel_fwhm': 5.22, 'snr_threshold': 3.0, 'sharplo': 0.2, 'sharphi': 1.0, 'roundlo': -1.0, 'roundhi': 1.0, 'brightest': 1000, 'peakmax': None, 'bkg_boxsize': 400, 'enforce_user_order': False, 'expand_refcat': True, 'minobj': 5, 'searchrad': 1, 'use2dhist': True, 'separation': 0.1, 'tolerance': 0.5, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3, 'abs_refcat': 'GAIADR3', 'save_abs_catalog': False, 'abs_minobj': 4, 'abs_searchrad': 6.0, 'abs_use2dhist': True, 'abs_separation': 0.1, 'abs_tolerance': 0.7, 'abs_fitgeometry': 'rshift', 'abs_nclip': 3, 'abs_sigma': 3.0}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/skymatch/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'local', 'match_down': True, 'subtract': True, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/outlier_detection/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'exptime', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '3.0 2.0', 'scale': '0.4 0.3', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/resample/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 0.8, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': 0, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.1, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/source_catalog/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 5.27, 'snr_threshold': 5.0, 'npixels': 5, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2024-01-03 22:34:39,188 - stpipe.Image3Pipeline - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-01-03 22:34:39,318 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2024-01-03 22:34:39,321 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf'.
# 2024-01-03 22:34:39,322 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_apcorr_0010.fits'.
# 2024-01-03 22:34:39,322 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/data/public/jwst_crds/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2024-01-03 22:34:39,323 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2024-01-03 22:34:39,339 - stpipe.Image3Pipeline - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2024-01-03 22:34:39,982 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2024-01-03 22:34:39,984 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/tweakreg/', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'use_custom_catalogs': False, 'catalog_format': 'ecsv', 'catfile': '', 'kernel_fwhm': 5.22, 'snr_threshold': 3.0, 'sharplo': 0.2, 'sharphi': 1.0, 'roundlo': -1.0, 'roundhi': 1.0, 'brightest': 1000, 'peakmax': None, 'bkg_boxsize': 400, 'enforce_user_order': False, 'expand_refcat': True, 'minobj': 5, 'searchrad': 1, 'use2dhist': True, 'separation': 0.1, 'tolerance': 0.5, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'shift', 'nclip': 3, 'sigma': 3, 'abs_refcat': 'GAIADR3', 'save_abs_catalog': False, 'abs_minobj': 4, 'abs_searchrad': 6.0, 'abs_use2dhist': True, 'abs_separation': 0.1, 'abs_tolerance': 0.7, 'abs_fitgeometry': 'rshift', 'abs_nclip': 3, 'abs_sigma': 3.0}
# 2024-01-03 22:34:40,478 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 511 sources in jw01837028001_06101_00001_mirimage_cal_stprm_bgsub.fits.
# 2024-01-03 22:34:40,979 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 627 sources in jw01837028001_06101_00002_mirimage_cal_stprm_bgsub.fits.
# 2024-01-03 22:34:41,479 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 579 sources in jw01837028001_08101_00001_mirimage_cal_stprm_bgsub.fits.
# 2024-01-03 22:34:41,978 - stpipe.Image3Pipeline.tweakreg - INFO - Detected 597 sources in jw01837028001_08101_00002_mirimage_cal_stprm_bgsub.fits.
# 2024-01-03 22:34:41,989 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:41,989 - stpipe.Image3Pipeline.tweakreg - INFO - Number of image groups to be aligned: 4.
# 2024-01-03 22:34:41,990 - stpipe.Image3Pipeline.tweakreg - INFO - Image groups:
# 2024-01-03 22:34:42,011 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01837028001_06101_00001_mirimage_cal_stprm_bgsub':
# 2024-01-03 22:34:42,012 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01837028001_06101_00001_mirimage_cal_stprm_bgsub
# 2024-01-03 22:34:42,033 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01837028001_06101_00002_mirimage_cal_stprm_bgsub':
# 2024-01-03 22:34:42,033 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01837028001_06101_00002_mirimage_cal_stprm_bgsub
# 2024-01-03 22:34:42,054 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01837028001_08101_00001_mirimage_cal_stprm_bgsub':
# 2024-01-03 22:34:42,054 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01837028001_08101_00001_mirimage_cal_stprm_bgsub
# 2024-01-03 22:34:42,076 - stpipe.Image3Pipeline.tweakreg - INFO - * Images in GROUP 'jw01837028001_08101_00002_mirimage_cal_stprm_bgsub':
# 2024-01-03 22:34:42,076 - stpipe.Image3Pipeline.tweakreg - INFO -      jw01837028001_08101_00002_mirimage_cal_stprm_bgsub
# 2024-01-03 22:34:42,076 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:42,077 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:42,077 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() started on 2024-01-03 22:34:42.077101
# 2024-01-03 22:34:42,077 - stpipe.Image3Pipeline.tweakreg - INFO -       Version 0.8.3
# 2024-01-03 22:34:42,078 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:44,188 - stpipe.Image3Pipeline.tweakreg - INFO - Selected image 'GROUP ID: jw01837028001_06101_00001_mirimage_cal_stprm_bgsub' as reference image
# 2024-01-03 22:34:44,195 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: jw01837028001_08101_00001_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2024-01-03 22:34:44,306 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01837028001_08101_00001_mirimage_cal_stprm_bgsub' catalog with sources from the reference 'jw01837028001_06101_00001_mirimage_cal_stprm_bgsub' catalog.
# 2024-01-03 22:34:44,307 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2024-01-03 22:34:44,309 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of 0.108, 0.1443 (arcsec) with significance of 60.18 and 120 matches.
# 2024-01-03 22:34:44,310 - stpipe.Image3Pipeline.tweakreg - INFO - Found 127 matches for 'GROUP ID: jw01837028001_08101_00001_mirimage_cal_stprm_bgsub'...
# 2024-01-03 22:34:44,311 - stpipe.Image3Pipeline.tweakreg - INFO - Performing 'shift' fit
# 2024-01-03 22:34:44,313 - stpipe.Image3Pipeline.tweakreg - INFO - Computed 'shift' fit for GROUP ID: jw01837028001_08101_00001_mirimage_cal_stprm_bgsub:
# 2024-01-03 22:34:44,313 - stpipe.Image3Pipeline.tweakreg - INFO - XSH: -0.00110686  YSH: -0.0138534
# 2024-01-03 22:34:44,314 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:44,314 - stpipe.Image3Pipeline.tweakreg - INFO - FIT RMSE: 0.091522   FIT MAE: 0.0656579
# 2024-01-03 22:34:44,314 - stpipe.Image3Pipeline.tweakreg - INFO - Final solution based on 119 objects.
# 2024-01-03 22:34:44,364 - stpipe.Image3Pipeline.tweakreg - INFO - Added 452 unmatched sources from 'GROUP ID: jw01837028001_08101_00001_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2024-01-03 22:34:44,976 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: jw01837028001_06101_00002_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2024-01-03 22:34:45,089 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01837028001_06101_00002_mirimage_cal_stprm_bgsub' catalog with sources from the reference 'jw01837028001_08101_00001_mirimage_cal_stprm_bgsub' catalog.
# 2024-01-03 22:34:45,089 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2024-01-03 22:34:45,092 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of 0.1129, 0.1357 (arcsec) with significance of 16.3 and 52 matches.
# 2024-01-03 22:34:45,093 - stpipe.Image3Pipeline.tweakreg - INFO - Found 76 matches for 'GROUP ID: jw01837028001_06101_00002_mirimage_cal_stprm_bgsub'...
# 2024-01-03 22:34:45,094 - stpipe.Image3Pipeline.tweakreg - INFO - Performing 'shift' fit
# 2024-01-03 22:34:45,096 - stpipe.Image3Pipeline.tweakreg - INFO - Computed 'shift' fit for GROUP ID: jw01837028001_06101_00002_mirimage_cal_stprm_bgsub:
# 2024-01-03 22:34:45,096 - stpipe.Image3Pipeline.tweakreg - INFO - XSH: -0.0732727  YSH: -0.0671758
# 2024-01-03 22:34:45,096 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:45,097 - stpipe.Image3Pipeline.tweakreg - INFO - FIT RMSE: 0.278634   FIT MAE: 0.243619
# 2024-01-03 22:34:45,097 - stpipe.Image3Pipeline.tweakreg - INFO - Final solution based on 76 objects.
# 2024-01-03 22:34:45,149 - stpipe.Image3Pipeline.tweakreg - INFO - Added 554 unmatched sources from 'GROUP ID: jw01837028001_06101_00002_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2024-01-03 22:34:45,560 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: jw01837028001_08101_00002_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2024-01-03 22:34:45,672 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01837028001_08101_00002_mirimage_cal_stprm_bgsub' catalog with sources from the reference 'jw01837028001_06101_00002_mirimage_cal_stprm_bgsub' catalog.
# 2024-01-03 22:34:45,673 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2024-01-03 22:34:45,677 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of 0.1458, 0.15 (arcsec) with significance of 26.19 and 146 matches.
# 2024-01-03 22:34:45,679 - stpipe.Image3Pipeline.tweakreg - INFO - Found 183 matches for 'GROUP ID: jw01837028001_08101_00002_mirimage_cal_stprm_bgsub'...
# 2024-01-03 22:34:45,679 - stpipe.Image3Pipeline.tweakreg - INFO - Performing 'shift' fit
# 2024-01-03 22:34:45,681 - stpipe.Image3Pipeline.tweakreg - INFO - Computed 'shift' fit for GROUP ID: jw01837028001_08101_00002_mirimage_cal_stprm_bgsub:
# 2024-01-03 22:34:45,681 - stpipe.Image3Pipeline.tweakreg - INFO - XSH: -0.0841265  YSH: -0.0818564
# 2024-01-03 22:34:45,682 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:45,682 - stpipe.Image3Pipeline.tweakreg - INFO - FIT RMSE: 0.231582   FIT MAE: 0.168217
# 2024-01-03 22:34:45,682 - stpipe.Image3Pipeline.tweakreg - INFO - Final solution based on 183 objects.
# 2024-01-03 22:34:45,737 - stpipe.Image3Pipeline.tweakreg - INFO - Added 419 unmatched sources from 'GROUP ID: jw01837028001_08101_00002_mirimage_cal_stprm_bgsub' to the reference catalog.
# 2024-01-03 22:34:45,737 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:45,737 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() ended on 2024-01-03 22:34:45.737536
# 2024-01-03 22:34:45,738 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() TOTAL RUN TIME: 0:00:03.660435
# 2024-01-03 22:34:45,738 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:47,540 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:47,541 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() started on 2024-01-03 22:34:47.540755
# 2024-01-03 22:34:47,541 - stpipe.Image3Pipeline.tweakreg - INFO -       Version 0.8.3
# 2024-01-03 22:34:47,541 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:50,464 - stpipe.Image3Pipeline.tweakreg - INFO - Aligning image catalog 'GROUP ID: 987654' to the reference catalog.
# 2024-01-03 22:34:50,578 - stpipe.Image3Pipeline.tweakreg - INFO - Matching sources from 'jw01837028001_0' catalog with sources from the reference 'Unnamed' catalog.
# 2024-01-03 22:34:50,579 - stpipe.Image3Pipeline.tweakreg - INFO - Computing initial guess for X and Y shifts...
# 2024-01-03 22:34:50,580 - stpipe.Image3Pipeline.tweakreg - INFO - Found initial X and Y shifts of -4.78, -2.783 (arcsec) with significance of 2 and 2 matches.
# 2024-01-03 22:34:50,581 - stpipe.Image3Pipeline.tweakreg - INFO - Found 1 matches for 'GROUP ID: 987654'...
# 2024-01-03 22:34:50,581 - stpipe.Image3Pipeline.tweakreg - WARNING - Not enough matches (< 1) found for image catalog 'GROUP ID: 987654'.
# 2024-01-03 22:34:50,582 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:50,582 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() ended on 2024-01-03 22:34:50.582463
# 2024-01-03 22:34:50,583 - stpipe.Image3Pipeline.tweakreg - INFO - ***** tweakwcs.imalign.align_wcs() TOTAL RUN TIME: 0:00:03.041708
# 2024-01-03 22:34:50,583 - stpipe.Image3Pipeline.tweakreg - INFO -
# 2024-01-03 22:34:50,778 - stpipe.Image3Pipeline.tweakreg - INFO - Saved model in ./stage3/tweakreg/jw01837028001_06101_00001_mirimage_cal_stprm_bgsub_tweakreg.fits
# 2024-01-03 22:34:50,961 - stpipe.Image3Pipeline.tweakreg - INFO - Saved model in ./stage3/tweakreg/jw01837028001_06101_00002_mirimage_cal_stprm_bgsub_tweakreg.fits
# 2024-01-03 22:34:51,143 - stpipe.Image3Pipeline.tweakreg - INFO - Saved model in ./stage3/tweakreg/jw01837028001_08101_00001_mirimage_cal_stprm_bgsub_tweakreg.fits
# 2024-01-03 22:34:51,502 - stpipe.Image3Pipeline.tweakreg - INFO - Saved model in ./stage3/tweakreg/jw01837028001_08101_00002_mirimage_cal_stprm_bgsub_tweakreg.fits
# 2024-01-03 22:34:51,503 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2024-01-03 22:34:51,640 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2024-01-03 22:34:51,642 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/skymatch/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'local', 'match_down': True, 'subtract': True, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}
# 2024-01-03 22:34:51,723 - stpipe.Image3Pipeline.skymatch - INFO -
# 2024-01-03 22:34:51,724 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() started on 2024-01-03 22:34:51.723923
# 2024-01-03 22:34:51,724 - stpipe.Image3Pipeline.skymatch - INFO -
# 2024-01-03 22:34:51,725 - stpipe.Image3Pipeline.skymatch - INFO - Sky computation method: 'local'
# 2024-01-03 22:34:51,725 - stpipe.Image3Pipeline.skymatch - INFO - Sky subtraction from image data: ON
# 2024-01-03 22:34:51,725 - stpipe.Image3Pipeline.skymatch - INFO -
# 2024-01-03 22:34:51,726 - stpipe.Image3Pipeline.skymatch - INFO - ----  Sky values computed per image and/or image groups.
# 2024-01-03 22:34:51,781 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01837028001_06101_00001_mirimage_cal_stprm_bgsub_tweakreg.fits. Sky background: 0.0047501 (old=0, delta=0.0047501)
# 2024-01-03 22:34:51,783 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01837028001_06101_00002_mirimage_cal_stprm_bgsub_tweakreg.fits. Sky background: -0.0218673 (old=0, delta=-0.0218673)
# 2024-01-03 22:34:51,784 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01837028001_08101_00001_mirimage_cal_stprm_bgsub_tweakreg.fits. Sky background: -0.0185978 (old=0, delta=-0.0185978)
# 2024-01-03 22:34:51,785 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=jw01837028001_08101_00002_mirimage_cal_stprm_bgsub_tweakreg.fits. Sky background: -0.0280303 (old=0, delta=-0.0280303)
# 2024-01-03 22:34:51,786 - stpipe.Image3Pipeline.skymatch - INFO -
# 2024-01-03 22:34:51,786 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() ended on 2024-01-03 22:34:51.786033
# 2024-01-03 22:34:51,786 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() TOTAL RUN TIME: 0:00:00.062110
# 2024-01-03 22:34:51,786 - stpipe.Image3Pipeline.skymatch - INFO -
# 2024-01-03 22:34:51,993 - stpipe.Image3Pipeline.skymatch - INFO - Saved model in ./stage3/skymatch/CosmicOwl_F1800W_0_skymatch.fits
# 2024-01-03 22:34:52,172 - stpipe.Image3Pipeline.skymatch - INFO - Saved model in ./stage3/skymatch/CosmicOwl_F1800W_1_skymatch.fits
# 2024-01-03 22:34:52,352 - stpipe.Image3Pipeline.skymatch - INFO - Saved model in ./stage3/skymatch/CosmicOwl_F1800W_2_skymatch.fits
# 2024-01-03 22:34:52,533 - stpipe.Image3Pipeline.skymatch - INFO - Saved model in ./stage3/skymatch/CosmicOwl_F1800W_3_skymatch.fits
# 2024-01-03 22:34:52,533 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2024-01-03 22:34:52,675 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2024-01-03 22:34:52,677 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/outlier_detection/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'exptime', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '3.0 2.0', 'scale': '0.4 0.3', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2024-01-03 22:34:52,686 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 4 inputs
# 2024-01-03 22:34:52,686 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter kernel: square
# 2024-01-03 22:34:52,686 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2024-01-03 22:34:52,687 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2024-01-03 22:34:52,687 - stpipe.Image3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2024-01-03 22:34:52,687 - stpipe.Image3Pipeline.outlier_detection - INFO - Output pixel scale ratio: 1.0
# 2024-01-03 22:34:52,830 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2024-01-03 22:34:53,200 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1023, 1044)
# 2024-01-03 22:34:53,534 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in CosmicOwl_F1800W_0_outlier_i2d.fits
# 2024-01-03 22:34:53,542 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2024-01-03 22:34:53,942 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1023, 1044)
# 2024-01-03 22:34:54,275 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in CosmicOwl_F1800W_1_outlier_i2d.fits
# 2024-01-03 22:34:54,284 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2024-01-03 22:34:54,682 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1023, 1044)
# 2024-01-03 22:34:55,015 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in CosmicOwl_F1800W_2_outlier_i2d.fits
# 2024-01-03 22:34:55,023 - stpipe.Image3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2024-01-03 22:34:55,425 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1023, 1044)
# 2024-01-03 22:34:55,759 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in CosmicOwl_F1800W_3_outlier_i2d.fits
# 2024-01-03 22:34:55,892 - stpipe.Image3Pipeline.outlier_detection - INFO - Computing median
# 2024-01-03 22:34:59,059 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_0_a3001_median.fits
# 2024-01-03 22:34:59,065 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median
# 2024-01-03 22:34:59,147 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:330: RuntimeWarning: invalid value encountered in multiply
#   blotted_median.err *= 0.0  # None
#
# 2024-01-03 22:34:59,537 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1023, 1044)
# 2024-01-03 22:34:59,737 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_0_a3001_blot.fits
# 2024-01-03 22:34:59,819 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:330: RuntimeWarning: invalid value encountered in multiply
#   blotted_median.err *= 0.0  # None
#
# 2024-01-03 22:35:00,210 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1023, 1044)
# 2024-01-03 22:35:00,410 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_1_a3001_blot.fits
# 2024-01-03 22:35:00,640 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:330: RuntimeWarning: invalid value encountered in multiply
#   blotted_median.err *= 0.0  # None
#
# 2024-01-03 22:35:01,027 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1023, 1044)
# 2024-01-03 22:35:01,227 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_2_a3001_blot.fits
# 2024-01-03 22:35:01,309 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:330: RuntimeWarning: invalid value encountered in multiply
#   blotted_median.err *= 0.0  # None
#
# 2024-01-03 22:35:01,703 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1023, 1044)
# 2024-01-03 22:35:01,902 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_3_a3001_blot.fits
# 2024-01-03 22:35:01,903 - stpipe.Image3Pipeline.outlier_detection - INFO - Flagging outliers
# 2024-01-03 22:35:02,065 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:437: RuntimeWarning: overflow encountered in multiply
#   threshold1 = scale1 * blot_deriv + snr1 * err_data
#
# 2024-01-03 22:35:02,079 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:446: RuntimeWarning: overflow encountered in multiply
#   threshold2 = scale2 * blot_deriv + snr2 * err_data
#
# 2024-01-03 22:35:02,086 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 75623 (7.16%)
# 2024-01-03 22:35:02,256 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:437: RuntimeWarning: overflow encountered in multiply
#   threshold1 = scale1 * blot_deriv + snr1 * err_data
#
# 2024-01-03 22:35:02,270 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:446: RuntimeWarning: overflow encountered in multiply
#   threshold2 = scale2 * blot_deriv + snr2 * err_data
#
# 2024-01-03 22:35:02,277 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 73490 (6.95%)
# 2024-01-03 22:35:02,441 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:437: RuntimeWarning: overflow encountered in multiply
#   threshold1 = scale1 * blot_deriv + snr1 * err_data
#
# 2024-01-03 22:35:02,455 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:446: RuntimeWarning: overflow encountered in multiply
#   threshold2 = scale2 * blot_deriv + snr2 * err_data
#
# 2024-01-03 22:35:02,462 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 68482 (6.48%)
# 2024-01-03 22:35:02,627 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:437: RuntimeWarning: overflow encountered in multiply
#   threshold1 = scale1 * blot_deriv + snr1 * err_data
#
# 2024-01-03 22:35:02,641 - stpipe.Image3Pipeline.outlier_detection - WARNING - /data/home/mingyu/opt/miniconda3/envs/jwst_latest/lib/python3.10/site-packages/jwst/outlier_detection/outlier_detection.py:446: RuntimeWarning: overflow encountered in multiply
#   threshold2 = scale2 * blot_deriv + snr2 * err_data
#
# 2024-01-03 22:35:02,649 - stpipe.Image3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 68079 (6.44%)
# 2024-01-03 22:35:02,854 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_0_a3001_crf.fits
# 2024-01-03 22:35:03,035 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_1_a3001_crf.fits
# 2024-01-03 22:35:03,217 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_2_a3001_crf.fits
# 2024-01-03 22:35:03,398 - stpipe.Image3Pipeline.outlier_detection - INFO - Saved model in ./stage3/outlier_detection/CosmicOwl_F1800W_3_a3001_crf.fits
# 2024-01-03 22:35:03,399 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2024-01-03 22:35:03,542 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2024-01-03 22:35:03,544 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/resample/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 0.8, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': 0, 'pixel_scale_ratio': 1.0, 'pixel_scale': 0.1, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2024-01-03 22:35:03,562 - stpipe.Image3Pipeline.resample - INFO - Using drizpars reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2024-01-03 22:35:03,584 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2024-01-03 22:35:03,584 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 0.8
# 2024-01-03 22:35:03,584 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2024-01-03 22:35:03,585 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2024-01-03 22:35:03,585 - stpipe.Image3Pipeline.resample - INFO - Output pixel scale: 0.1 arcsec.
# 2024-01-03 22:35:03,727 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for CosmicOwl_F1800W
# 2024-01-03 22:35:04,798 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2024-01-03 22:35:05,163 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:05,940 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:06,717 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:07,493 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:07,885 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2024-01-03 22:35:08,253 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:09,043 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:09,833 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:10,626 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:11,032 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2024-01-03 22:35:11,402 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:12,171 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:12,939 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:13,705 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:14,110 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2024-01-03 22:35:14,509 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:15,308 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:16,108 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:16,900 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1539, 1526)
# 2024-01-03 22:35:17,345 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  150.068208166 2.203442992 150.068208781 2.246192987 150.025787302 2.246192987 150.025787917 2.203442992
# 2024-01-03 22:35:17,887 - stpipe.Image3Pipeline.resample - INFO - Saved model in ./stage3/resample/CosmicOwl_F1800W_i2d.fits
# 2024-01-03 22:35:17,888 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2024-01-03 22:35:18,033 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(1539, 1526) from CosmicOwl_F1800W_i2d.fits>,).
# 2024-01-03 22:35:18,035 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': './stage3/source_catalog/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 5.27, 'snr_threshold': 5.0, 'npixels': 5, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2024-01-03 22:35:18,051 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_apcorr_0010.fits
# 2024-01-03 22:35:18,060 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /data/public/jwst_crds/references/jwst/miri/jwst_miri_abvegaoffset_0001.asdf
# 2024-01-03 22:35:18,061 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: MIRI
# 2024-01-03 22:35:18,061 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: MIRIMAGE
# 2024-01-03 22:35:18,061 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: F1800W
# 2024-01-03 22:35:18,062 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2024-01-03 22:35:18,119 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 6.22752
# 2024-01-03 22:35:18,185 - stpipe.Image3Pipeline.source_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1539, 1526).
# 2024-01-03 22:35:20,706 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 34 sources
# 2024-01-03 22:35:20,896 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: ./stage3/source_catalog/CosmicOwl_F1800W_cat.ecsv
# 2024-01-03 22:35:21,047 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in ./stage3/source_catalog/CosmicOwl_F1800W_segm.fits
# 2024-01-03 22:35:21,049 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: CosmicOwl_F1800W_segm.fits
# 2024-01-03 22:35:21,050 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2024-01-03 22:35:21,056 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done
